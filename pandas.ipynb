# %%
#Importing pandas

import pandas as pd
print(pd.__version__)
# Out:
# 2.1.3

# %%
#Read Files in Pandas
data = pd.read_csv('vgsales.csv')
data
pd.DataFrame(data)
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#Print Data from Top
data.head()
data.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
#Print Data from Bottom
data.tail()
data.tail(15)
# Out:
#         Rank                                               Name Platform  \
# 16583  16586                                     Carmageddon 64      N64
# 16584  16587                                   Bust-A-Move 3000       GC
# 16585  16588                                             Breach       PC
# 16586  16589                     Secret Files 2: Puritas Cordis       DS
# 16587  16590                           Mezase!! Tsuri Master DS       DS
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# ...

# %%
#Converting Data into Dataframe or Table
data2 = {'Name' : ["Sumeet", "Harsh", "Sakshi"],
         'Age' : [6,5,3]
         }

data2
pd.DataFrame(data2)
# Out:
#      Name  Age
# 0  Sumeet    6
# 1   Harsh    5
# 2  Sakshi    3

# %%
#Converting Data to CSV
data2 = {'Name': ['John', 'Alice', 'Bob'],
        'Age': [25, 30, 35],
        'City': ['New York', 'San Francisco', 'Los Angeles']}

df = pd.DataFrame(data2)

df.to_csv('output.csv', index=False)

# %%
#Information about Data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
#Describe Data 
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
#Selecting Specific Column
gameNames = data["Name"]
gameNamesRank = data[["Name", "Rank"]]
gameNamesRank
# Out:
#                                                    Name   Rank
# 0                                            Wii Sports      1
# 1                                     Super Mario Bros.      2
# 2                                        Mario Kart Wii      3
# 3                                     Wii Sports Resort      4
# 4                              Pokemon Red/Pokemon Blue      5
# ...                                                 ...    ...
# 16593                Woody Woodpecker in Crazy Castle 5  16596
# 16594                     Men in Black II: Alien Escape  16597
# 16595  SCORE International Baja 1000: The Official Game  16598
# 16596                                        Know How 2  16599
# 16597                                  Spirits & Spells  16600
#
# [16598 rows x 2 columns]

# %%
#Printing no of Col and Rows
data.shape
# Out:
# (16598, 11)

# %%
#Showing True for more than 2006
data['Year'] >= 2006
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 16593    False
# 16594    False
# 16595     True
# 16596     True
# 16597    False
# Name: Year, Length: 16598, dtype: bool

# %%
#Remove Columns
data.drop(columns=['Year', 'Platform'])
# Out:
#         Rank                                              Name         Genre  \
# 0          1                                        Wii Sports        Sports
# 1          2                                 Super Mario Bros.      Platform
# 2          3                                    Mario Kart Wii        Racing
# 3          4                                 Wii Sports Resort        Sports
# 4          5                          Pokemon Red/Pokemon Blue  Role-Playing
# ...      ...                                               ...           ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      Platform
# 16594  16597                     Men in Black II: Alien Escape       Shooter
# 16595  16598  SCORE International Baja 1000: The Official Game        Racing
# 16596  16599                                        Know How 2        Puzzle
# 16597  16600                                  Spirits & Spells      Platform
#
# ...

# %%
# Convert strings to lowercase
data['Name'] = data['Name'].str.lower()

# Convert strings to uppercase
data['Genre'] = data['Genre'].str.upper()
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        wii sports      Wii
# 1          2                                 super mario bros.      NES
# 2          3                                    mario kart wii      Wii
# 3          4                                 wii sports resort      Wii
# 4          5                          pokemon red/pokemon blue       GB
# ...      ...                                               ...      ...
# 16593  16596                woody woodpecker in crazy castle 5      GBA
# 16594  16597                     men in black ii: alien escape       GC
# 16595  16598  score international baja 1000: the official game      PS2
# 16596  16599                                        know how 2       DS
# 16597  16600                                  spirits & spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#Check whether data has Null Values
data.isnull()
data.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
# Remove rows with any missing values
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
# Remove leading and trailing whitespaces from strings in a column
data['Name'] = data['Name'].str.strip()
# Out:
# 0                                              wii sports
# 1                                       super mario bros.
# 2                                          mario kart wii
# 3                                       wii sports resort
# 4                                pokemon red/pokemon blue
#                                ...
# 16593                  woody woodpecker in crazy castle 5
# 16594                       men in black ii: alien escape
# 16595    score international baja 1000: the official game
# 16596                                          know how 2
# 16597                                    spirits & spells
# Name: Name, Length: 16291, dtype: object

# %%
data.replace(" ", "", regex=True, inplace=True)
data
# Out:
#         Rank                                        Name Platform    Year  \
# 0          1                                   wiisports      Wii  2006.0
# 1          2                             supermariobros.      NES  1985.0
# 2          3                                mariokartwii      Wii  2008.0
# 3          4                             wiisportsresort      Wii  2009.0
# 4          5                      pokemonred/pokemonblue       GB  1996.0
# ...      ...                                         ...      ...     ...
# 16593  16596               woodywoodpeckerincrazycastle5      GBA  2002.0
# 16594  16597                    meninblackii:alienescape       GC  2003.0
# 16595  16598  scoreinternationalbaja1000:theofficialgame      PS2  2008.0
# 16596  16599                                    knowhow2       DS  2010.0
# 16597  16600                              spirits&spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
# Remove duplicate rows based on all columns
data.drop_duplicates()
# Out:
#         Rank                                        Name Platform    Year  \
# 0          1                                   wiisports      Wii  2006.0
# 1          2                             supermariobros.      NES  1985.0
# 2          3                                mariokartwii      Wii  2008.0
# 3          4                             wiisportsresort      Wii  2009.0
# 4          5                      pokemonred/pokemonblue       GB  1996.0
# ...      ...                                         ...      ...     ...
# 16593  16596               woodywoodpeckerincrazycastle5      GBA  2002.0
# 16594  16597                    meninblackii:alienescape       GC  2003.0
# 16595  16598  scoreinternationalbaja1000:theofficialgame      PS2  2008.0
# 16596  16599                                    knowhow2       DS  2010.0
# 16597  16600                              spirits&spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
# Convert a column to a different data type
data['Rank'] = data['Rank'].astype('float')
data
# Out:
#           Rank                                        Name Platform    Year  \
# 0          1.0                                   wiisports      Wii  2006.0
# 1          2.0                             supermariobros.      NES  1985.0
# 2          3.0                                mariokartwii      Wii  2008.0
# 3          4.0                             wiisportsresort      Wii  2009.0
# 4          5.0                      pokemonred/pokemonblue       GB  1996.0
# ...        ...                                         ...      ...     ...
# 16593  16596.0               woodywoodpeckerincrazycastle5      GBA  2002.0
# 16594  16597.0                    meninblackii:alienescape       GC  2003.0
# 16595  16598.0  scoreinternationalbaja1000:theofficialgame      PS2  2008.0
# 16596  16599.0                                    knowhow2       DS  2010.0
# 16597  16600.0                              spirits&spells      GBA  2003.0
#
# ...

# %%
# Rename columns
data.rename(columns={'Name': 'Original_Name'}, inplace=True)
data
# Out:
#           Rank                               Original_Name Platform    Year  \
# 0          1.0                                   wiisports      Wii  2006.0
# 1          2.0                             supermariobros.      NES  1985.0
# 2          3.0                                mariokartwii      Wii  2008.0
# 3          4.0                             wiisportsresort      Wii  2009.0
# 4          5.0                      pokemonred/pokemonblue       GB  1996.0
# ...        ...                                         ...      ...     ...
# 16593  16596.0               woodywoodpeckerincrazycastle5      GBA  2002.0
# 16594  16597.0                    meninblackii:alienescape       GC  2003.0
# 16595  16598.0  scoreinternationalbaja1000:theofficialgame      PS2  2008.0
# 16596  16599.0                                    knowhow2       DS  2010.0
# 16597  16600.0                              spirits&spells      GBA  2003.0
#
# ...
